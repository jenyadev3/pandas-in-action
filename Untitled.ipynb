# %%
import pandas as pd
import numpy as np

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
ice_cream_flavours = [
    "Chocolate", "Vanilla", "Strawberry"
]

days_of_week = ["Monday", "Wednesday","Friday"]

pd.Series(data=ice_cream_flavours,index=days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# dtype: object

# %%
lucky_numbers = [4,8,15,16]
pd.Series(lucky_numbers)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# dtype: int64

# %%
pd.Series(lucky_numbers, dtype=float)
# Out:
# 0     4.0
# 1     8.0
# 2    15.0
# 3    16.0
# dtype: float64
